# %% [markdown]
# 1. Write a Python program to check that a string contains only a certain set of characters (in this case a-z, A-Z and 0-9).

# %%
import re
test_str=input("enter the string :")
patt=re.compile(r'[a-zA-z0-9]+$')
res=patt.match(test_str)
if res:
  print('\n the string containsonly a-z, A-Z and 0-9')
else:
  print("\nother characters are also present")
# Out:
# enter the string :learn python
#
# other characters are also present

# %% [markdown]
# 2. Write a Python program that matches a string that has an a followed by zero or more b's.

# %%
import re
pat=r'\ba[b]*'
text=input('Enter a string :')
x=re.findall(pat, text)
if x:
  print("Match found:",x)
else:print("Match not found")
# Out:
# Enter a string :['ab;] ,'a'
# Match found: ['ab', 'a']

# %% [markdown]
# 4.Write a Python program that matches a string that has an a followed by three 'b'.

# %%
import re
pat=r'a[b]{3}'
text=input('enter a string :')
x=re.findall(pat,text)
if x:
  print("match found:",x)
else:print("match not foundd")
# Out:
# enter a string :abbcd abbbcd babbbbc
# match found: ['abbb', 'abbb']

# %% [markdown]
# 3.replace only the 1st occurence of 5 for with given string

# %%
import re
ip='they ate 5 apples and 5 oranges'
op=re.sub("5","five",ip,1)
print(op)
# Out:
# they ate five apples and 5 oranges

# %% [markdown]
# 5. Write a Python program that matches a string that has an 'a' followed by anything ending in 'b'.

# %%
import re
def fun(test_str):
    pattern=r"^a.+b$"
    if re.search(pattern,test_str):
      print('the string matches the pattern')
    else:
      print("string does not  match the pattern")
      fun("abb")
      fun("abgfdgh")

# %% [markdown]
# the string matches the pattern
# string does ot match the pattern

# %% [markdown]
# 6. Write a Python program to search for numbers (0-9) of length between 1 and 3 in a given string.

# %%
import re
txt="exercises number 1, 12, 13 and 345 are important"
pattern=r'\b[0-9]{1,3}\b'
x=re.findall(pattern,txt)
print(x)
# Out:
# ['1', '12', '13', '345']

# %% [markdown]
# 7. Write a Python program to search for literal strings within a string.\
# Sample text : 'The quick brown fox jumps over the lazy dog.' \
# Searched words : 'fox', 'dog', 'horse'

# %%
import re
words=['fox', 'dog','hprse']
text='the quick brown fox jumps over the lazydog.'
for i in words:
  if re.search(i,text):
    print(f" '{i}' is found in '{text}'")
  else:
      print(f" '{i}' is not found in'{text}'")
# Out:
#  'fox' is found in 'the quick brown fox jumps over the lazydog.'
#  'dog' is found in 'the quick brown fox jumps over the lazydog.'
#  'hprse' is not found in'the quick brown fox jumps over the lazydog.'

# %% [markdown]
# 8. Write a Python program to search for a literal string in a string and also find the location within the original string where the pattern occurs.
#
# Sample text : 'The quick brown fox jumps over the lazy dog.' \
# Searched words : 'fox'

# %%
import re
word='fox'
text='the quick brown fox jumps over the lazy dog.'
x=re.search(word,text)
print(f" '{word}' is found in '{text}' at a position of '{x.start()}-{x.end()}'")
# Out:
#  'fox' is found in 'the quick brown fox jumps over the lazy dog.' at a position of '16-19'

# %% [markdown]
# 9.  Write a Python program to extract year, month and date from an URL

# %%
import re
url1= "https://www.washingtonpost.com/news/football-insider/wp/2016/09/02/odell-beckhams-fame-rests-on-one-stupid-little-ball-josh-norman-tells-author/"
pattern=r'\d{4/\d{1,2}/\d{1,2}'
x=re.findall(pattern,url1)
print(x)
# Out:
# []

# %%
import re
url1= "https://www.washingtonpost.com/news/football-insider/wp/2016/09/02/odell-beckhams-fame-rests-on-one-stupid-little-ball-josh-norman"
p=re.compile('\d{4}/\d{2}/\d{2}/')
print(p.findall(url1))
# Out:
# ['2016/09/02/']

# %% [markdown]
# 10. Write a Python program to find URLs in a string.

# %%
import re
text= '<p>contents :,/p><a href="https://w3resource.com">python examples</a><a href="http://github.com">even more examples</a>'
pattern='http[S]?\://\W+\.\W+'
x=re.findall(pattern,text)
print(x)
# Out:
# []

# %% [markdown]
#  ['https://w3resource.com', 'http://github.com]

# %% [markdown]
# 11. Write a Python program to remove the parenthesis area in a string.\
#
# Sample data : ["example (.com)", "w3resource", "github (.com)", "stackoverflow (.com)"] \
# Expected Output: \
# example  \
# w3resource \
# github  \
# stackoverflow. \

# %%
import re
data=["example(.com)", "w3resource", "github(.com), " "stackoverflow(.com)"]
for pat in data:
  res=re.sub(r'\(\.\w+\)','',pat)
print (res)
# Out:
# github, stackoverflow

# %% [markdown]
# Sample data : ["example (.com)", "w3resource", "github (.com)", "stackoverflow (.com)"]
# Expected Output:
# example
# w3resource
# github
# stackoverflow.

# %% [markdown]
# 12. Write a Python program to concatenate the consecutive numbers in a given string. \
#
# Original string:  \
# Enter at 1 20 Kearny Street. The security desk can direct you to floor 1 6. Please have your identification ready.  \
#
# After concatenating the consecutive numbers in the said string:  \
# Enter at 120 Kearny Street. The security desk can direct you to floor 16. Please have your identification ready.

# %%
import re
ip_string='enter at 1 20kearny street. the security desk can direct you to floor 1 6. please have your identification ready.'
p=re.compile(r'(?<=\d)()(?=\d)')
res=p.sub('',ip_string)
print(res)
# Out:
# enter at 1 20kearny street. the security desk can direct you to floor 1 6. please have your identification ready.
