# %%
import math
class circle:
  radius=0.0
  pi=math.pi
  def area(self):
    print("area of circle:",self.pi*self.radius**2)
    def perimeter(self):
      print("perimeter of circle:",2*self.pi*self.radius)
      circle1=circl2()
      circle1.radius=12
      circle1.area()
      circle1.perimeter()

# %% [markdown]
# area of circle:452.3893421169302perimeter of circle:75.39822368615503

# %% [markdown]
#  Write a Python program to create a calculator class. Include methods for basic arithmetic operations.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
class calculator:
  def __init__(self,a,b):
    self.a=a
    self.b=b
  def addition(self):
    return self.a+self.b
  def substraction(self):
    return self.a-self.b
  def multipication(self):
    return self.a*self.b
  def division(self):
    return self.a/self.b
  def modulus(self):
    return self.a%self.b
    c=calculator(40,20) #a=40,b=20
    a=c.addition()
    s=c.substraction()
    m=c.division()
    md=c.modulus()

    print("addition:",a)
    print("substraction:",s)
    print("multipication:",m)
    print("division:",m)
    print("modulus",md)

# %% [markdown]
# addition:60
# substraction:20
# multipication:800
# division:2.0
# modulus:0

# %% [markdown]
# Write a Python program to create a class representing a Circle. Include methods to calculate its area and perimeter.

# %%
class calculator:
  def add(self,a,b):
    return a+b
  def sub(self,a,b):
    return a-b
  def multiply(self,a,b):
    return a*b
  def devide(self,a,b):
   if a!=0:
    return a/b
   else:
    return"cannot divide by zero"
  def modulus(self,a,b):
   return a%b

#create object an instance of the calculator class
c=calculator()

result_addition=c.add(5,10)
result_subtraction=c.sub(8,4)
result_multipication=c.multiply(5,2)
result_division=c.devide(12,4)
result_modulus=c.modulus(9,4)

print("sum of numbers=",result_addition)
print("diffrence of numbers=",result_subtraction)
print("product of numbers=",result_multipication)
print("quotient of numbers=",result_division)
print("modulus of thenumbers",result_modulus)
# Out:
# sum of numbers= 15
# diffrence of numbers= 4
# product of numbers= 10
# quotient of numbers= 3.0
# modulus of thenumbers 1

# %% [markdown]
# sum of numbers=15
# diffrence of numbers=4
# product of nunbers=10
# quotient of numbers=3.0
# modulus of the numbers=1

# %% [markdown]
# Write a Python program to create a class that represents a shape. Include methods to calculate its area and perimeter. Implement subclasses for different shapes like circle, triangle, and square

# %%
import math
class shape():
     def area(self):
         pass
     def perimeter(self):
         pass
class circle(shape):
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return math.pi*self.radius**2
    def perimeter(self):
        return 2*math.pi*self.radius
class triangle(shape):
     def __init__(self,side1,side2,side3):
         self.side1=side2
         self.side2=side2
         self.side3=side3
     def area(self):
         s=(self.side1+self.side2+self.side3)/2
         return math.sqrt(s*(s-self.side1)*(s-self.side2)*(s-self.side3))
     def perimeter(self):
          return self.side1+self.side2+self.side3
class square(shape):
     def __init__(self,side):
         self.side=side
     def area(self):
         return self.side**2
     def perimeter(self):
         return 4*self.side
circle=circle(5)
triangle=triangle(3,4,5)
square=square(6)

print("circle:  Area=",circle.area(),"perimeter=",circle.perimeter())
print("triangle: Area=",triangle.area(),"perimeter=",triangle.perimeter())
print("square: Area=",square.area(),"perimeter=",square.perimeter())
# Out:
# circle:  Area= 78.53981633974483 perimeter= 31.41592653589793
# triangle: Area= 7.806247497997997 perimeter= 13
# square: Area= 36 perimeter= 24

# %% [markdown]
# a
